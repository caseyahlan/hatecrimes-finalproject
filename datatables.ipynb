# %%
from IPython.display import HTML
HTML('''
<style>
.prompt {
  display: none;
}
</style>
<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <style>
# .prompt {
#   display: none;
# }
# </style>
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # Data tables
#
#
# ### Below are the data tables we consulted in our analysis. (after data preparation)
# [Return to analysis](analysis.ipynb)

# %%
import pandas as pd

data_538 = pd.read_csv("./data/hate_crimes.csv")
off_by_bias_motivation = pd.read_csv("./data/table_1_incidents_offenses_victims_and_known_offenders_by_bias_motivation_2016.csv")
off_by_off_type = pd.read_csv("./data/table_2_incidents_offenses_victims_and_known_offenders_by_offense_type_2016.csv")
off_race_by_off_type = pd.read_csv("./data/table_3_offenses_known_offenders_race_and_ethnicity_by_offense_type_2016.csv")
off_type_by_bias_motivation = pd.read_csv("./data/table_4_offenses_offense_type_by_bias_motivation_2016.csv")
off_race_by_bias_motivation = pd.read_csv("./data/table_5_offenses_known_offenders_race_and_ethnicity_by_bias_motivation_2016.csv")
off_by_state = pd.read_csv("./data/table_11_offenses_offense_type_by_participating_state_2016.csv")
locations = pd.read_csv("./data/table_10_incidents_bias_motivation_by_location_2016.csv")

# %% [markdown]
# ## Hate Crimes data from 538
#
# Shows demographic and hate crime data from each state.

# %%
data_538
# Out:
#    code                 state  median_household_income  \
# 0    AL               Alabama                    42278
# 1    AK                Alaska                    67629
# 2    AZ               Arizona                    49254
# 3    AR              Arkansas                    44922
# 4    CA            California                    60487
# 5    CO              Colorado                    60940
# 6    CT           Connecticut                    70161
# 7    DE              Delaware                    57522
# 8    DC  District of Columbia                    68277
# 9    FL               Florida                    46140
# 10   GA               Georgia                    49555
# 11   HI                Hawaii                    71223
# 12   ID                 Idaho                    53438
# 13   IL              Illinois                    54916
# 14   IN               Indiana                    48060
# 15   IA                  Iowa                    57810
# ...

# %% [markdown]
# ## Incidents, Offenses, Victims, and Known Offenders by Offense Type
#
# FBI data

# %%
off_by_bias_motivation[['Bias motivation', 'Incidents', 'Offenses', 'Victims', 'Known offenders']][0:34]
# Out:
#                                       Bias motivation  Incidents  Offenses  \
# 0                                          Anti-White        720       876
# 1                      Anti-Black or African American       1739      2122
# 2               Anti-American Indian or Alaska Native        154       161
# 3                                          Anti-Asian        113       131
# 4      Anti-Native Hawaiian or Other Pacific Islander          9         9
# 5                          Anti-Multiple Races, Group        136       178
# 6                                           Anti-Arab         51        56
# 7                             Anti-Hispanic or Latino        344       449
# 8                  Anti-Other Race/Ethnicity/Ancestry        223       247
# 9                                         Anti-Jewish        684       834
# 10                                      Anti-Catholic         62        63
# ...

# %% [markdown]
# ## Offenses by offense type

# %%
off_by_off_type[['offense_type', 'Incidents', 'Offenses', 'Victims', 'Known offenders']][0:15]
# Out:
#                             offense_type  Incidents  Offenses  Victims  \
# 0   Murder and nonnegligent manslaughter          5         9        9
# 1              Rape (revised definition)         24        24       24
# 2               Rape (legacy definition)          0         0        0
# 3                     Aggravated assault        684       873      873
# 4                         Simple assault       1458      1687     1687
# 5                           Intimidation       1577      2109     2109
# 6                                Robbery        134       134      163
# 7                               Burglary        123       123      138
# 8                          Larceny-theft        231       231      253
# 9                    Motor vehicle theft         20        20       21
# 10                                 Arson         39        39       51
# 11          Destruction/damage/vandalism       1913      1913     2122
# ...

# %% [markdown]
# ## Known offender by offense type

# %%
off_race_by_off_type[0:15]
# Out:
#                             Offense type  Total  White  \
# 0   Murder and nonnegligent manslaughter      9      4
# 1              Rape (revised definition)     24      9
# 2               Rape (legacy definition)      0      0
# 3                     Aggravated assault    873    395
# 4                         Simple assault   1687    764
# 5                           Intimidation   2109   1015
# 6           Other crimes against persons     18     10
# 7                                Robbery    134     25
# 8                               Burglary    123     33
# 9                          Larceny-theft    231     69
# 10                   Motor vehicle theft     20      3
# 11                                 Arson     39     13
# 12          Destruction/damage/vandalism   1913    267
# 13         Other crimes against property     59     19
# 14                Crimes against society     82     54
#
#     Black or African\nAmerican  American Indian or Alaska Native  Asian  \
# ...

# %% [markdown]
# ## Offense type by bias motivation

# %%
off_type_by_bias_motivation[0:35]
# Out:
#                                       Bias motivation  Total  \
# 0                                          Anti-White    876
# 1                      Anti-Black or African American   2122
# 2               Anti-American Indian or Alaska Native    161
# 3                                          Anti-Asian    131
# 4      Anti-Native Hawaiian or Other Pacific Islander      9
# 5                          Anti-Multiple Races, Group    178
# 6                                           Anti-Arab     56
# 7                             Anti-Hispanic or Latino    449
# 8                  Anti-Other Race/Ethnicity/Ancestry    247
# 9                                         Anti-Jewish    834
# 10                                      Anti-Catholic     63
# 11                                    Anti-Protestant     20
# 12                              Anti-Islamic (Muslim)    381
# 13                                Anti-Other Religion     90
# ...

# %% [markdown]
# ## Offender race by bias motivation

# %%
off_race_by_bias_motivation[['White', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Native Hawaiian or Other Pacific Islander', 'Group of multiple races', 'Unknown race', 'Unknown offender']][0:35]
# Out:
#     White  Black or African American  American Indian or Alaska Native  Asian  \
# 0     133                        452                                20      6
# 1    1142                         80                                 9     17
# 2      56                         28                                 2      0
# 3      65                         20                                 2      6
# 4       4                          4                                 0      0
# 5      54                         33                                 0      1
# 6      32                          6                                 0      1
# 7     228                        114                                 2      0
# 8      61                         44                                 2      1
# 9     156                         34                                 4      0
# 10      9                          3                                 0      2
# ...

# %% [markdown]
# ## Offender ethnicity by bias motivation

# %%
off_race_by_bias_motivation[['Hispanic or Latino', 'Not Hispanic or Latino', 'Group of multiple ethnicities', 'Unknown ethnicity', 'Unknown offender']][0:35]
# Out:
#     Hispanic or Latino  Not Hispanic or Latino  Group of multiple ethnicities  \
# 0                   22                     169                              9
# 1                   82                     267                              5
# 2                    1                       3                              0
# 3                    6                      28                              3
# 4                    0                       1                              0
# 5                    2                      31                              1
# 6                    4                      16                              0
# 7                   15                     112                              2
# 8                    3                      35                              2
# 9                    9                      16                              4
# 10                   4                       3                              0
# ...

# %% [markdown]
# ## Offense type by state

# %%
off_by_state[1::]
# Out:
#                    state  total  Murder and nonnegligent manslaughter  \
# 1                Alabama     17                                     0
# 2                 Alaska     13                                     0
# 3                Arizona    291                                     0
# 4               Arkansas     15                                     0
# 5             California   1142                                     0
# 6               Colorado    126                                     0
# 7            Connecticut    124                                     0
# 8               Delaware     19                                     0
# 9   District of Columbia    127                                     0
# 10               Florida    110                                     0
# 11               Georgia     46                                     0
# 12                 Idaho     35                                     1
# ...

# %% [markdown]
# ## Bias motivation by location type

# %%
locations[1::]
# Out:
#                                          Location  Total incidents  \
# 1                   Abandoned/condemned structure                5
# 2                          Air/bus/train terminal               94
# 3                                  Amusement park                1
# 4              Arena/stadium/fairgrounds/coliseum                6
# 5                          ATM separate from bank                1
# 6                        Auto dealership new/used                6
# 7                           Bank/savings and loan               20
# 8                                   Bar/nightclub               96
# 9                                 Camp/campground                3
# 10                 Church/synagogue/temple/mosque              241
# 11                     Commercial office building              117
# 12                               Community center               11
# 13                              Construction site               19
# ...
